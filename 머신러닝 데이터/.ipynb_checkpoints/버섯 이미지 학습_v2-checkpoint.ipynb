# %%
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import torchvision
from torchvision import transforms

# %% [markdown]
# # 211016
# Russula 92번 이미지 깨져서 삭제
# 깨진 이미지 있어도 진행하는 방법이 있어서 해보았으나 처리가 안됨

# %%
def imshow(img):
    img = img /2 + 0.5 # unnormalize
    np_img = img.numpy()
    # plt.imshow(np_img)
    plt.imshow(np.transpose(np_img, (1,2,0)))
    
    print(np_img.shape)
    print((np.transpose(np_img,(1,2,0))).shape)

# %%
import os

os.listdir('./Mushrooms_images')
# Out:
# ['Agaricus',
#  'Amanita',
#  'Boletus',
#  'Cortinarius',
#  'Entoloma',
#  'Hygrocybe',
#  'Lactarius',
#  'Russula',
#  'Suillus']

# %% [markdown]
# # 211018
# train_test_split 이용 테스트 셋, 트레인 셋 분리

# %%
from sklearn.model_selection import train_test_split

trans = transforms.Compose([transforms.Resize((32,32)),
                           transforms.ToTensor(),
                           transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
                           ])

imageData = torchvision.datasets.ImageFolder(root = "./Mushrooms_images",
                                           transform = trans)

trainset, testset = train_test_split(imageData, test_size=0.2)

# %%
len(trainset)
# Out:
# 5370

# %%
len(testset)
# Out:
# 1343

# %%
trainloader = DataLoader(trainset,
                        batch_size = 10,
                        shuffle = True,
                        num_workers = 2)

testloader = DataLoader(testset,
                        batch_size = 10,
                        shuffle = False,
                        num_workers = 2)

# %%
classes = imageData.classes
classes
# Out:
# ['Agaricus',
#  'Amanita',
#  'Boletus',
#  'Cortinarius',
#  'Entoloma',
#  'Hygrocybe',
#  'Lactarius',
#  'Russula',
#  'Suillus']

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()
print(labels)
# Out:
# tensor([8, 4, 7, 7, 1, 7, 3, 7, 1, 1])

# %%
print(images.shape)
imshow(torchvision.utils.make_grid(images, nrow=10)) # imshow 함수 호출
print(images.shape)
print((torchvision.utils.make_grid(images)).shape)
print("".join("%5s "%classes[labels[j]] for j in range(4)))
# Out:
# torch.Size([10, 3, 32, 32])
# (3, 36, 342)
# (36, 342, 3)
# torch.Size([10, 3, 32, 32])
# torch.Size([3, 70, 274])
# Suillus Entoloma Russula Russula

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5) # kernel=5, paddig=0. stride=1. 32-5+1=28
        self.pool = nn.MaxPool2d(2, 2)  # 14
        self.conv2 = nn.Conv2d(6, 16, 5) # kernel=5, paddig=0. stride=1. 14-5+1=10 => max pooling 후 5X5
        self.fc1 = nn.Linear(16 * 5 * 5, 120) 
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 9)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # 배치를 제외한 모든 차원을 평탄화(flatten)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# # 211017
# Adam으로 변경, momentum 0.9와 0.999로 변화

# %%
import torch.optim as optim

net = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999))

# %% [markdown]
# # 211017
# running_loss 계산 식 수정

# %%
for epoch in range(20):   # 데이터셋을 수차례 반복합니다.

    running_loss = 0.0
    
    for i, data in enumerate(trainloader, 0):
        # [inputs, labels]의 목록인 data로부터 입력을 받은 후;
        inputs, labels = data
        # 변화도(Gradient) 매개변수를 0으로 만들고
        optimizer.zero_grad()

        # 순전파 + 역전파 + 최적화를 한 후
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # 통계를 출력합니다.
        running_loss += loss.item()
        if i % 100 == 99:    
            print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 100))
            running_loss = 0.0

print('Finished Training')
# Out:
# [1,   100] loss: 2.085
# [1,   200] loss: 2.058
# [1,   300] loss: 1.918
# [1,   400] loss: 1.921
# [1,   500] loss: 1.911
# [2,   100] loss: 1.869
# [2,   200] loss: 1.818
# [2,   300] loss: 1.826
# [2,   400] loss: 1.874
# [2,   500] loss: 1.780
# [3,   100] loss: 1.729
# [3,   200] loss: 1.759
# [3,   300] loss: 1.747
# [3,   400] loss: 1.753
# [3,   500] loss: 1.711
# [4,   100] loss: 1.688
# [4,   200] loss: 1.669
# [4,   300] loss: 1.667
# [4,   400] loss: 1.633
# [4,   500] loss: 1.634
# [5,   100] loss: 1.592
# [5,   200] loss: 1.633
# [5,   300] loss: 1.566
# [5,   400] loss: 1.561
# [5,   500] loss: 1.579
# [6,   100] loss: 1.504
# [6,   200] loss: 1.472
# [6,   300] loss: 1.557
# [6,   400] loss: 1.532
# [6,   500] loss: 1.525
# [7,   100] loss: 1.391
# [7,   200] loss: 1.417
# [7,   300] loss: 1.467
# [7,   400] loss: 1.533
# [7,   500] loss: 1.416
# [8,   100] loss: 1.338
# [8,   200] loss: 1.360
# [8,   300] loss: 1.381
# [8,   400] loss: 1.376
# [8,   500] loss: 1.369
# [9,   100] loss: 1.282
# [9,   200] loss: 1.255
# [9,   300] loss: 1.278
# [9,   400] loss: 1.270
# [9,   500] loss: 1.274
# [10,   100] loss: 1.139
# [10,   200] loss: 1.146
# [10,   300] loss: 1.158
# [10,   400] loss: 1.188
# [10,   500] loss: 1.167
# [11,   100] loss: 1.003
# [11,   200] loss: 1.018
# [11,   300] loss: 1.106
# [11,   400] loss: 1.090
# [11,   500] loss: 1.117
# [12,   100] loss: 0.870
# [12,   200] loss: 0.891
# [12,   300] loss: 0.971
# [12,   400] loss: 0.941
# [12,   500] loss: 1.015
# [13,   100] loss: 0.802
# [13,   200] loss: 0.787
# [13,   300] loss: 0.815
# [13,   400] loss: 0.891
# [13,   500] loss: 0.890
# [14,   100] loss: 0.654
# [14,   200] loss: 0.674
# [14,   300] loss: 0.685
# [14,   400] loss: 0.829
# [14,   500] loss: 0.788
# [15,   100] loss: 0.613
# [15,   200] loss: 0.576
# [15,   300] loss: 0.609
# [15,   400] loss: 0.671
# [15,   500] loss: 0.669
# [16,   100] loss: 0.468
# [16,   200] loss: 0.503
# [16,   300] loss: 0.551
# [16,   400] loss: 0.506
# [16,   500] loss: 0.599
# [17,   100] loss: 0.374
# [17,   200] loss: 0.406
# [17,   300] loss: 0.430
# [17,   400] loss: 0.456
# [17,   500] loss: 0.527
# [18,   100] loss: 0.315
# [18,   200] loss: 0.348
# [18,   300] loss: 0.353
# [18,   400] loss: 0.451
# [18,   500] loss: 0.426
# [19,   100] loss: 0.267
# [19,   200] loss: 0.257
# [19,   300] loss: 0.325
# [19,   400] loss: 0.372
# [19,   500] loss: 0.370
# [20,   100] loss: 0.260
# [20,   200] loss: 0.265
# [20,   300] loss: 0.263
# [20,   400] loss: 0.327
# [20,   500] loss: 0.433
# Finished Training

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()
#images, labels = dataiter.next()
# 이미지를 출력합니다.
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# (3, 70, 274)
# (70, 274, 3)
# GroundTruth:  Lactarius Boletus Agaricus Agaricus

# %%
outputs = net(images)

# %%
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:  Boletus Boletus Agaricus Agaricus

# %%
dataiter = iter(trainloader)
correct = 0
for i in range(250):
    images, labels = dataiter.next()
    outputs = net(images)
    _, predicted = torch.max(outputs, 1)
    #print('답: ', labels)
    #print('예측 : ', predicted)
    for j in range(10):  
        if labels[j] == predicted[j]:
            correct += 1

print('%.3f' % (correct/(i*10) * 100), '%')
# Out:
# 92.209 %

# %%
dataiter = iter(testloader)
correct = 0
for i in range(100):
    images, labels = dataiter.next()
    outputs = net(images)
    _, predicted = torch.max(outputs, 1)
    #print('답: ', labels)
    #print('예측 : ', predicted)
    for j in range(10):  
        if labels[j] == predicted[j]:
            correct += 1

print('%.3f' % (correct/(i*10) * 100), '%')
# Out:
# 답:  tensor([4, 2, 6, 2, 7, 1, 4, 6, 6, 7])
# 예측 :  tensor([6, 7, 8, 2, 0, 5, 1, 7, 6, 6])
# 답:  tensor([0, 7, 6, 2, 6, 3, 2, 5, 8, 2])
# 예측 :  tensor([7, 7, 7, 7, 2, 7, 7, 8, 3, 2])
# 답:  tensor([7, 6, 2, 2, 6, 2, 8, 6, 6, 8])
# 예측 :  tensor([6, 6, 6, 2, 8, 4, 6, 6, 6, 7])
# 답:  tensor([6, 7, 1, 6, 3, 2, 0, 7, 6, 7])
# 예측 :  tensor([6, 5, 2, 7, 3, 2, 6, 6, 6, 6])
# 답:  tensor([2, 2, 2, 2, 2, 6, 7, 3, 2, 4])
# 예측 :  tensor([2, 2, 7, 6, 6, 3, 7, 4, 6, 7])
# 답:  tensor([2, 6, 8, 6, 7, 3, 8, 5, 7, 0])
# 예측 :  tensor([6, 3, 3, 6, 7, 1, 1, 5, 3, 7])
# 답:  tensor([3, 6, 6, 3, 4, 4, 8, 7, 6, 6])
# 예측 :  tensor([3, 1, 6, 6, 0, 2, 2, 6, 7, 6])
# 답:  tensor([2, 3, 2, 6, 2, 3, 6, 2, 1, 1])
# 예측 :  tensor([2, 1, 2, 7, 6, 3, 7, 1, 2, 1])
# 답:  tensor([4, 6, 2, 3, 3, 1, 8, 4, 2, 2])
# 예측 :  tensor([5, 2, 4, 0, 7, 1, 6, 5, 2, 2])
# 답:  tensor([2, 0, 7, 8, 1, 6, 6, 2, 7, 1])
# 예측 :  tensor([2, 3, 4, 3, 1, 6, 6, 2, 7, 6])
# 답:  tensor([0, 7, 1, 7, 3, 6, 8, 2, 4, 3])
# 예측 :  tensor([0, 3, 3, 7, 2, 7, 6, 5, 6, 1])
# 답:  tensor([2, 7, 7, 8, 6, 7, 2, 7, 7, 3])
# 예측 :  tensor([2, 7, 6, 6, 7, 1, 1, 3, 7, 7])
# 답:  tensor([0, 6, 5, 1, 1, 7, 6, 8, 6, 7])
# 예측 :  tensor([6, 3, 3, 1, 4, 7, 4, 2, 7, 1])
# 답:  tensor([2, 2, 1, 7, 3, 3, 6, 3, 6, 1])
# 예측 :  tensor([2, 5, 7, 4, 4, 6, 5, 7, 6, 1])
# 답:  tensor([3, 1, 5, 6, 7, 6, 2, 0, 1, 6])
# 예측 :  tensor([7, 6, 3, 6, 7, 3, 7, 7, 2, 7])
# 답:  tensor([7, 7, 6, 4, 3, 1, 2, 3, 6, 3])
# 예측 :  tensor([6, 6, 6, 6, 6, 3, 3, 8, 6, 5])
# 답:  tensor([6, 1, 7, 7, 8, 2, 6, 2, 7, 7])
# 예측 :  tensor([4, 1, 6, 6, 3, 6, 0, 1, 1, 6])
# 답:  tensor([6, 6, 2, 2, 4, 6, 3, 6, 1, 6])
# 예측 :  tensor([2, 7, 2, 2, 8, 6, 6, 0, 7, 7])
# 답:  tensor([3, 5, 3, 8, 0, 6, 7, 6, 1, 1])
# 예측 :  tensor([3, 5, 8, 2, 1, 6, 6, 1, 7, 2])
# 답:  tensor([7, 6, 1, 7, 7, 6, 6, 7, 2, 5])
# 예측 :  tensor([7, 6, 1, 5, 5, 1, 7, 2, 3, 6])
# 답:  tensor([3, 5, 7, 7, 3, 6, 8, 7, 1, 1])
# 예측 :  tensor([7, 6, 6, 8, 1, 7, 3, 7, 6, 3])
# 답:  tensor([3, 5, 8, 5, 3, 6, 2, 6, 1, 3])
# 예측 :  tensor([7, 2, 6, 3, 2, 6, 3, 6, 6, 6])
# 답:  tensor([2, 5, 7, 8, 2, 6, 7, 1, 2, 3])
# 예측 :  tensor([4, 6, 3, 4, 6, 2, 7, 3, 5, 3])
# 답:  tensor([7, 1, 0, 7, 6, 8, 2, 5, 3, 7])
# 예측 :  tensor([7, 6, 0, 7, 7, 6, 6, 6, 6, 6])
# 답:  tensor([6, 2, 4, 2, 5, 7, 1, 6, 5, 7])
# 예측 :  tensor([5, 6, 6, 6, 8, 1, 3, 7, 5, 7])
# 답:  tensor([2, 7, 4, 7, 4, 7, 1, 0, 6, 6])
# 예측 :  tensor([2, 0, 7, 7, 4, 7, 1, 1, 6, 6])
# 답:  tensor([7, 2, 2, 6, 6, 4, 0, 1, 3, 6])
# 예측 :  tensor([3, 6, 6, 7, 6, 4, 7, 2, 6, 6])
# 답:  tensor([1, 4, 6, 7, 7, 5, 7, 7, 1, 1])
# 예측 :  tensor([1, 8, 6, 3, 7, 3, 6, 4, 1, 6])
# 답:  tensor([6, 7, 2, 1, 7, 6, 7, 5, 6, 6])
# 예측 :  tensor([7, 5, 2, 2, 6, 7, 7, 7, 7, 6])
# 답:  tensor([1, 7, 3, 7, 7, 2, 6, 1, 1, 8])
# 예측 :  tensor([1, 3, 3, 7, 6, 8, 8, 2, 3, 8])
# 답:  tensor([7, 5, 6, 6, 3, 8, 3, 7, 1, 0])
# 예측 :  tensor([2, 0, 6, 6, 3, 6, 3, 6, 0, 1])
# 답:  tensor([3, 4, 8, 1, 6, 0, 6, 8, 3, 7])
# 예측 :  tensor([3, 3, 6, 3, 6, 7, 0, 6, 3, 6])
# 답:  tensor([6, 6, 2, 7, 1, 6, 1, 6, 1, 6])
# 예측 :  tensor([6, 6, 2, 0, 1, 6, 6, 6, 1, 1])
# 답:  tensor([8, 1, 3, 6, 0, 6, 7, 6, 3, 3])
# 예측 :  tensor([6, 3, 2, 6, 0, 6, 6, 6, 7, 3])
# 답:  tensor([6, 2, 1, 3, 8, 3, 3, 6, 2, 3])
# 예측 :  tensor([6, 6, 3, 6, 8, 6, 2, 8, 3, 1])
# 답:  tensor([2, 7, 4, 7, 2, 3, 7, 6, 3, 3])
# 예측 :  tensor([3, 7, 6, 3, 2, 3, 7, 7, 6, 6])
# 답:  tensor([0, 8, 6, 0, 7, 7, 2, 6, 5, 8])
# 예측 :  tensor([0, 7, 7, 6, 6, 7, 5, 6, 2, 1])
# 답:  tensor([8, 6, 5, 6, 6, 7, 3, 6, 2, 1])
# 예측 :  tensor([3, 6, 5, 6, 6, 6, 6, 2, 8, 2])
# 답:  tensor([6, 2, 6, 6, 6, 6, 4, 6, 2, 3])
# 예측 :  tensor([7, 2, 6, 6, 7, 6, 3, 2, 4, 5])
# 답:  tensor([6, 6, 1, 7, 4, 4, 2, 1, 5, 8])
# 예측 :  tensor([6, 5, 5, 4, 4, 2, 5, 3, 2, 3])
# 답:  tensor([4, 1, 1, 3, 0, 4, 6, 3, 2, 3])
# 예측 :  tensor([6, 1, 5, 3, 1, 0, 6, 8, 3, 6])
# 답:  tensor([2, 6, 6, 6, 6, 8, 1, 8, 5, 1])
# 예측 :  tensor([0, 6, 6, 7, 7, 7, 6, 1, 6, 1])
# 답:  tensor([6, 1, 1, 3, 3, 3, 3, 0, 2, 3])
# 예측 :  tensor([3, 6, 1, 8, 2, 6, 3, 7, 2, 4])
# 답:  tensor([4, 2, 3, 4, 3, 6, 5, 7, 3, 1])
# 예측 :  tensor([6, 2, 2, 3, 6, 2, 5, 7, 3, 1])
# 답:  tensor([0, 7, 2, 6, 6, 6, 0, 4, 0, 2])
# 예측 :  tensor([6, 6, 2, 6, 2, 6, 4, 6, 6, 3])
# 답:  tensor([3, 1, 3, 6, 6, 7, 4, 2, 8, 6])
# 예측 :  tensor([7, 2, 7, 0, 7, 7, 6, 3, 3, 6])
# 답:  tensor([6, 1, 6, 6, 6, 6, 6, 6, 6, 0])
# 예측 :  tensor([6, 6, 1, 6, 6, 8, 7, 7, 3, 0])
# 답:  tensor([6, 4, 1, 3, 7, 3, 8, 8, 3, 6])
# 예측 :  tensor([8, 7, 1, 6, 0, 3, 7, 3, 5, 6])
# 답:  tensor([6, 0, 8, 6, 3, 2, 8, 8, 2, 3])
# 예측 :  tensor([5, 0, 6, 6, 2, 2, 6, 3, 2, 3])
# 답:  tensor([7, 2, 6, 7, 2, 6, 7, 1, 6, 5])
# 예측 :  tensor([1, 2, 6, 6, 2, 2, 6, 1, 6, 5])
# 답:  tensor([3, 2, 6, 2, 5, 6, 1, 3, 0, 3])
# 예측 :  tensor([0, 2, 6, 2, 6, 6, 7, 6, 0, 3])
# 답:  tensor([6, 6, 2, 5, 5, 0, 6, 2, 6, 5])
# 예측 :  tensor([6, 6, 2, 5, 6, 0, 7, 2, 6, 4])
# 답:  tensor([7, 2, 7, 7, 3, 7, 7, 1, 6, 5])
# 예측 :  tensor([5, 6, 7, 7, 6, 7, 5, 1, 3, 5])
# 답:  tensor([3, 6, 3, 6, 2, 7, 7, 8, 1, 3])
# 예측 :  tensor([1, 6, 3, 6, 2, 3, 7, 3, 1, 3])
# 답:  tensor([2, 7, 6, 2, 6, 3, 6, 1, 6, 6])
# 예측 :  tensor([2, 8, 6, 2, 6, 1, 7, 1, 3, 6])
# 답:  tensor([1, 6, 7, 3, 1, 3, 8, 3, 6, 2])
# 예측 :  tensor([6, 6, 6, 7, 0, 5, 3, 3, 6, 3])
# 답:  tensor([1, 6, 7, 7, 7, 7, 6, 6, 3, 6])
# 예측 :  tensor([4, 6, 7, 7, 7, 6, 7, 6, 6, 6])
# 답:  tensor([7, 3, 6, 6, 1, 3, 2, 2, 2, 1])
# 예측 :  tensor([7, 4, 2, 8, 1, 3, 2, 3, 2, 3])
# 답:  tensor([5, 5, 3, 7, 6, 6, 1, 7, 2, 0])
# 예측 :  tensor([5, 2, 6, 6, 7, 6, 0, 6, 6, 6])
# 답:  tensor([7, 1, 2, 5, 0, 3, 1, 4, 6, 0])
# 예측 :  tensor([7, 2, 6, 5, 3, 1, 6, 3, 8, 2])
# 답:  tensor([6, 2, 4, 2, 7, 2, 6, 7, 3, 7])
# 예측 :  tensor([7, 2, 6, 2, 4, 6, 6, 2, 2, 7])
# 답:  tensor([2, 0, 8, 2, 6, 3, 6, 1, 7, 4])
# 예측 :  tensor([2, 3, 5, 2, 2, 0, 8, 0, 5, 6])
# 답:  tensor([6, 0, 4, 2, 5, 1, 2, 3, 2, 7])
# 예측 :  tensor([3, 0, 6, 1, 5, 2, 2, 8, 2, 7])
# 답:  tensor([6, 6, 3, 2, 6, 7, 2, 6, 6, 6])
# 예측 :  tensor([6, 6, 0, 2, 0, 7, 2, 6, 7, 1])
# 답:  tensor([6, 6, 3, 7, 7, 6, 2, 6, 1, 2])
# 예측 :  tensor([7, 6, 1, 6, 7, 7, 7, 3, 3, 7])
# 답:  tensor([6, 3, 6, 6, 3, 6, 7, 0, 7, 1])
# 예측 :  tensor([2, 7, 6, 4, 6, 6, 7, 0, 6, 2])
# 답:  tensor([6, 2, 6, 6, 6, 6, 7, 6, 6, 6])
# 예측 :  tensor([6, 2, 3, 6, 6, 6, 6, 7, 6, 1])
# 답:  tensor([7, 6, 3, 3, 2, 7, 5, 6, 7, 1])
# 예측 :  tensor([0, 3, 6, 7, 5, 8, 5, 6, 7, 1])
# 답:  tensor([6, 0, 4, 4, 0, 2, 1, 7, 2, 6])
# 예측 :  tensor([3, 4, 7, 6, 6, 3, 7, 7, 6, 4])
# 답:  tensor([3, 7, 1, 1, 6, 7, 4, 6, 1, 2])
# 예측 :  tensor([3, 3, 2, 2, 6, 6, 6, 6, 1, 2])
# 답:  tensor([6, 6, 1, 7, 5, 8, 6, 1, 7, 7])
# 예측 :  tensor([6, 6, 1, 7, 7, 6, 7, 1, 3, 3])
# 답:  tensor([3, 1, 8, 0, 5, 3, 6, 7, 5, 3])
# 예측 :  tensor([2, 2, 6, 7, 6, 6, 6, 7, 5, 3])
# 답:  tensor([4, 2, 7, 0, 0, 0, 3, 6, 6, 8])
# 예측 :  tensor([3, 2, 7, 7, 0, 7, 6, 3, 6, 2])
# 답:  tensor([3, 3, 1, 2, 2, 0, 7, 6, 6, 3])
# 예측 :  tensor([4, 3, 6, 2, 7, 1, 7, 6, 3, 6])
# 답:  tensor([4, 8, 8, 7, 6, 0, 7, 2, 5, 6])
# 예측 :  tensor([3, 7, 7, 6, 7, 3, 6, 6, 7, 6])
# 답:  tensor([7, 8, 1, 8, 6, 6, 0, 4, 1, 1])
# 예측 :  tensor([6, 8, 4, 6, 4, 6, 1, 6, 8, 1])
# 답:  tensor([7, 0, 2, 2, 6, 6, 1, 6, 1, 6])
# 예측 :  tensor([7, 6, 1, 2, 8, 8, 4, 6, 0, 3])
# 답:  tensor([7, 2, 2, 5, 2, 6, 6, 4, 3, 3])
# 예측 :  tensor([3, 2, 7, 5, 2, 1, 2, 4, 7, 0])
# 답:  tensor([2, 7, 2, 6, 2, 2, 4, 7, 2, 6])
# 예측 :  tensor([2, 7, 6, 6, 7, 2, 5, 7, 6, 6])
# 답:  tensor([1, 2, 4, 7, 4, 4, 7, 6, 6, 6])
# 예측 :  tensor([8, 2, 7, 4, 6, 2, 7, 6, 6, 5])
# 답:  tensor([2, 3, 7, 5, 1, 7, 3, 8, 1, 2])
# 예측 :  tensor([2, 7, 7, 5, 1, 6, 3, 6, 2, 3])
# 답:  tensor([2, 6, 0, 2, 2, 6, 6, 7, 3, 1])
# 예측 :  tensor([2, 3, 0, 6, 7, 6, 7, 6, 0, 6])
# 답:  tensor([0, 2, 2, 5, 8, 4, 2, 2, 2, 4])
# 예측 :  tensor([0, 2, 6, 5, 7, 6, 2, 2, 2, 2])
# 답:  tensor([3, 4, 6, 3, 8, 2, 7, 5, 3, 6])
# 예측 :  tensor([2, 6, 4, 7, 7, 2, 7, 7, 6, 6])
# 답:  tensor([6, 7, 7, 7, 2, 7, 8, 7, 6, 1])
# 예측 :  tensor([3, 7, 7, 8, 2, 6, 3, 3, 6, 6])
# 답:  tensor([3, 5, 5, 7, 3, 6, 6, 1, 6, 8])
# 예측 :  tensor([3, 6, 1, 7, 2, 6, 1, 5, 4, 1])
# 답:  tensor([0, 7, 4, 1, 2, 4, 6, 2, 7, 6])
# 예측 :  tensor([3, 6, 6, 2, 6, 3, 4, 2, 6, 6])
# 답:  tensor([0, 3, 1, 3, 1, 6, 6, 3, 1, 3])
# 예측 :  tensor([6, 8, 5, 3, 0, 6, 3, 6, 2, 3])
# 답:  tensor([7, 1, 0, 6, 5, 6, 2, 2, 2, 3])
# 예측 :  tensor([7, 7, 3, 2, 6, 7, 2, 2, 6, 3])
# 답:  tensor([6, 8, 2, 2, 7, 2, 2, 6, 7, 6])
# 예측 :  tensor([6, 3, 2, 8, 0, 1, 2, 6, 7, 6])
# 답:  tensor([4, 1, 1, 4, 5, 6, 8, 1, 6, 4])
# 예측 :  tensor([1, 6, 1, 3, 5, 0, 3, 1, 6, 6])
# 답:  tensor([2, 0, 7, 6, 3, 1, 4, 7, 4, 1])
# 예측 :  tensor([2, 0, 7, 7, 6, 2, 6, 7, 3, 1])
# 답:  tensor([1, 3, 7, 2, 8, 6, 7, 3, 6, 1])
# 예측 :  tensor([1, 5, 0, 2, 6, 6, 8, 7, 6, 1])
# 답:  tensor([4, 3, 4, 0, 0, 2, 6, 7, 1, 6])
# 예측 :  tensor([4, 6, 6, 1, 0, 6, 6, 7, 3, 1])
# 답:  tensor([1, 1, 7, 6, 2, 6, 1, 2, 2, 6])
# 예측 :  tensor([6, 3, 6, 6, 2, 6, 3, 2, 6, 0])
# 답:  tensor([6, 1, 5, 0, 6, 2, 6, 3, 1, 5])
# 예측 :  tensor([6, 1, 3, 0, 6, 2, 5, 1, 0, 3])
# 답:  tensor([7, 6, 3, 4, 2, 1, 6, 4, 4, 7])
# 예측 :  tensor([3, 5, 3, 5, 6, 3, 1, 7, 0, 7])
# 답:  tensor([7, 1, 7, 3, 2, 2, 1, 6, 2, 8])
# 예측 :  tensor([3, 7, 6, 3, 1, 2, 0, 6, 2, 6])
# 답:  tensor([1, 2, 6, 7, 7, 6, 7, 7, 6, 6])
# 예측 :  tensor([1, 6, 6, 7, 7, 6, 7, 3, 6, 6])
# 답:  tensor([7, 2, 6, 7, 3, 6, 6, 7, 6, 2])
# 예측 :  tensor([6, 8, 0, 6, 6, 4, 6, 6, 6, 2])
# 37.677 %
