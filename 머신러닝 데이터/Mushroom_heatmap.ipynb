# %% [markdown]
# <데이터 로드>

# %%
import numpy as np
import pandas as pd 
df = pd.read_csv('mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# * Class : 독성 분류 ; Edible(e) : 먹을 수 있는 / Poisonous(p) : 독성
# Attribute Information: (classes: edible=e, poisonous=p)
# <br /><br />
# * Cap : 버섯의 머리 부분
#  * shape : 모양
# cap-shape: bell=b, conical=c, convex=x, flat=f, knobbed=k,sunken=s
#  * surface : 표면(돌기)
# cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
#  * color : 색깔
# cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
# <br /><br />
# *  Bruises : 멍
# bruises: bruises=t,no=f
# <br /><br />
# * Odor : 냄새
# odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s
# <br /><br />
# * Gill : 버섯 머리 아래 주름
#  * attachment : 주름이 붙은 모양(형태)
# gill-attachment: attached=a,descending=d,free=f,notched=n
#  * spacing : 주름 사이 틈
# gill-spacing: close=c,crowded=w,distant=d
#  * size : 주름 하나 크기
# gill-size: broad=b,narrow=n
#  * color : 색깔
# gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y
# <br /><br />
# * Stalk : 줄기(버섯 몸통)
#  * shape : 생긴 모양
# stalk-shape: enlarging=e,tapering=t
#  * root : 뿌리 모양
# stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?
#  * surface-above-ring : ring 위 stalk 표면
# stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
#  * surface-below-ring : ring 아래 stalk 표면
# stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
#  * color-above-ring : ring 위 stalk 색깔
# stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
#  * color-below-ring : ring 아래 stalk 색깔
# stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# <br /><br />
# * Veil : 버섯 베일
#  * type : 베일의 모양
# veil-type: partial=p,universal=u
#  * color : 색깔
# veil-color: brown=n,orange=o,white=w,yellow=y
# <br /><br />
# * Ring(몸통 가운데 고리, 턱받이)
#  * number : 고리 숫자
# ring-number: none=n,one=o,two=t
#  * type : 종류
# ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z
# <br /><br />
# * Spor-print-color : 포자 무늬 색깔
# spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y
# <br /><br />
# * Population : 개체군(버섯끼리 모여 사는 정도) ; 같은 서식지에서 살고 있는 생물 개체들의 집단
# population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y
# <br /><br />
# * Habitat : 서식지
# habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d

# %% [markdown]
# ## 연관성 체크

# %% [markdown]
# < cap -shape : 연관성 낮음>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p','cap-shape_b', 'cap-shape_c', 'cap-shape_f', 'cap-shape_k', 'cap-shape_s', 'cap-shape_x']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < cap-surface >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'cap-surface_f', 'cap-surface_g', 'cap-surface_s', 'cap-surface_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < cap-color>

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'cap-color_b', 'cap-color_c', 'cap-color_e', 'cap-color_g', 'cap-color_n', 'cap-color_p'
                                , 'cap-color_r', 'cap-color_u', 'cap-color_w', 'cap-color_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# <bruises>

# %% [markdown]
# <bruises>

# %% [markdown]
# < bruises_t >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'bruises_t']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < odor >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'odor_a', 'odor_c', 'odor_f', 'odor_l',
                                'odor_m', 'odor_n', 'odor_p', 'odor_s', 'odor_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# <  gill-attachment_a >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p','gill-attachment_a']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < gill-spacing_c >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'gill-spacing_c']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < gill-size_b >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'gill-size_b']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < gill-color >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'gill-color_b', 'gill-color_e', 'gill-color_g', 'gill-color_h', 'gill-color_k', 'gill-color_n'
                                , 'gill-color_o', 'gill-color_p', 'gill-color_r', 'gill-color_u', 'gill-color_w', 'gill-color_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < stalk-shape_e >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'stalk-shape_e', 'stalk-shape_t']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < stalk-root >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'stalk-root_?', 'stalk-root_b', 'stalk-root_c', 'stalk-root_e', 'stalk-root_r']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < stalk-surface-above-ring, stalk-surface-below-ring>

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'stalk-surface-above-ring_f', 'stalk-surface-above-ring_k', 'stalk-surface-above-ring_s'
                                , 'stalk-surface-above-ring_y', 'stalk-surface-below-ring_f', 'stalk-surface-below-ring_k'
                                , 'stalk-surface-below-ring_s', 'stalk-surface-below-ring_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < stalk-color-above-ring >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'stalk-color-above-ring_b', 'stalk-color-above-ring_c', 'stalk-color-above-ring_e'
                                , 'stalk-color-above-ring_g', 'stalk-color-above-ring_n', 'stalk-color-above-ring_o'
                                , 'stalk-color-above-ring_p', 'stalk-color-above-ring_w', 'stalk-color-above-ring_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < stalk-color-below-ring >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'stalk-color-below-ring_b', 'stalk-color-below-ring_c', 'stalk-color-below-ring_e'
                                , 'stalk-color-below-ring_g', 'stalk-color-below-ring_n', 'stalk-color-below-ring_o'
                                , 'stalk-color-below-ring_p', 'stalk-color-below-ring_w', 'stalk-color-below-ring_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < veil-type >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'veil-type_p']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < veil-color >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'veil-color_n', 'veil-color_o', 'veil-color_w', 'veil-color_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < ring-number >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'ring-number_n', 'ring-number_o', 'ring-number_t']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < ring-type >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'ring-type_e', 'ring-type_f', 'ring-type_l', 'ring-type_n', 'ring-type_p']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# <  spore-print-color_b >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'spore-print-color_b', 'spore-print-color_h', 'spore-print-color_k', 'spore-print-color_n'
                                , 'spore-print-color_o', 'spore-print-color_r', 'spore-print-color_u', 'spore-print-color_w'
                                , 'spore-print-color_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < population >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'population_a', 'population_c', 'population_n', 'population_s'
                                , 'population_v', 'population_y']].corr().abs(), annot=True)
plt.show()

# %% [markdown]
# < habitat >

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(pd.get_dummies(df)[['class_p', 'habitat_d', 'habitat_g', 'habitat_l', 'habitat_m', 'habitat_p', 'habitat_u', 'habitat_w']].corr().abs(), annot=True)
plt.show()
